# %% [markdown]
# # OBJECT DETECTION PROJECT

# %% [markdown]
# # Trial

# %%
# Importing the required libraries

import os

import cv2 
import numpy as np
import object_detection
import tensorflow as tf
import time
import uuid

from google.protobuf import text_format

from matplotlib import pyplot as plt

from object_detection.builders import model_builder
from object_detection.protos import pipeline_pb2
from object_detection.utils import label_map_util, config_util
from object_detection.utils import visualization_utils as viz_utils

# %matplotlib inline

# %% [markdown]
# ## Defines images to collect

# %%
labels = ['apple', 'egg', 'tomato']
number_imgs = 4     # This is just for the trial, min images should be 10-20

# %% [markdown]
# ## Setup folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
        # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# ## Capture images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)       # connection to the webcam
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Image labelling

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py

# %% [markdown]
# ## Train and test samples

# %%
# Set up paths
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# ## Download Tensorflow pretrained model

# %%
# https://www.tensorflow.org/install/source_windows

if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}

# %% [markdown]
# ## Create label map

# %%
labels = [{'name':'apple', 'id':1}, {'name':'egg', 'id':2}, {'name':'tomato', 'id':3}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# Create TF records - TF records are a binary file format for storing data. They'll be use for training

# %%
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')

if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# copy model config to training folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 archivo(s) copiado(s).

# %% [markdown]
# ### Update config with our specific requirements

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 3
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# ### Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}
# Out:
# 2022-06-25 15:07:47.632037: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-25 15:07:48.679882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0625 15:07:48.813365 13868 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 2000
# I0625 15:07:48.817362 13868 config_util.py:552] Maybe overwriting train_steps: 2000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0625 15:07:48.817362 13868 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0625 15:07:48.840373 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I0625 15:07:48.847366 13868 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I0625 15:07:48.847366 13868 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0625 15:07:48.847366 13868 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0625 15:07:48.847366 13868 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0625 15:07:48.852360 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0625 15:07:48.883361 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0625 15:07:54.672415 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0625 15:07:57.317979 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0625 15:07:58.807665 13868 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\keras-2.9.0-py3.7.egg\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2022-06-25 15:08:20.164227: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401

# %% [markdown]
# ## Evaluate the model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0625 15:08:33.739290  3012 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0625 15:08:33.740290  3012 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0625 15:08:33.740290  3012 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0625 15:08:33.740290  3012 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0625 15:08:33.740290  3012 model_lib_v2.py:1110] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2022-06-25 15:08:33.742446: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-25 15:08:34.194846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I0625 15:08:34.329639  3012 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I0625 15:08:34.329639  3012 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0625 15:08:34.329639  3012 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0625 15:08:34.329639  3012 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0625 15:08:34.331639  3012 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0625 15:08:34.353642  3012 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0625 15:08:37.770901  3012 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0625 15:08:38.749280  3012 deprecation.py:356] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# I0625 15:08:40.961719  3012 checkpoint_utils.py:136] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet\ckpt-3
# I0625 15:08:40.968718  3012 checkpoint_utils.py:145] Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet\ckpt-3
# c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\keras-2.9.0-py3.7.egg\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2022-06-25 15:09:02.251734: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401

# %% [markdown]
# ## Load train model

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# ## Detection from image

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'egg.c18ee526-efc7-11ec-b470-94085359aa66.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes'] + label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
#plt.savefig("test.png")
plt.show()

# %% [markdown]
# ## Real time dectection using webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# ## Freezing the graph

# %% [markdown]
# Saving a slice of the model to be able to use it next time.

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# 2022-06-26 16:22:56.624428: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-26 16:22:57.109819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0626 16:22:57.510465 10348 deprecation.py:628] From c:\Users\Usuario\Desktop\The_Bridge\side_projects\object_detection_project\env\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001AC08DE6348>, because it is not built.
# W0626 16:23:15.249702 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001AC08DE6348>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC1781B448>, because it is not built.
# W0626 16:23:15.540710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC1781B448>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17801088>, because it is not built.
# W0626 16:23:15.540710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17801088>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17801B08>, because it is not built.
# W0626 16:23:15.540710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17801B08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC17801DC8>, because it is not built.
# W0626 16:23:15.540710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC17801DC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1776B708>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1776B708>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176EC3C8>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176EC3C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC176ECA88>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC176ECA88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC176EC688>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC176EC688>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176F4D88>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176F4D88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC176F4E88>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001AC176F4E88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1780D108>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1780D108>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1780D808>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1780D808>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17681D08>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17681D08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1776ECC8>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1776ECC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1776E388>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1776E388>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC177410C8>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC177410C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC177417C8>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC177417C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17741F48>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17741F48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC176C20C8>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC176C20C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176C2488>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176C2488>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17642788>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17642788>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17833248>, because it is not built.
# W0626 16:23:15.541737 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17833248>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17833EC8>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17833EC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17890808>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17890808>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17890A08>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17890A08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17895048>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17895048>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17895588>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC17895588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1782E508>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC1782E508>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1782AB88>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1782AB88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17548588>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17548588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC177E8F08>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC177E8F08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178E46C8>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178E46C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178E4908>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178E4908>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178DF408>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178DF408>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178DFB88>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178DFB88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178DFC88>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178DFC88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1782ACC8>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1782ACC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176E4EC8>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC176E4EC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1769D348>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC1769D348>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178D5688>, because it is not built.
# W0626 16:23:15.542710 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178D5688>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178D5808>, because it is not built.
# W0626 16:23:15.543693 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178D5808>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178D5DC8>, because it is not built.
# W0626 16:23:15.543693 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC178D5DC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178163C8>, because it is not built.
# W0626 16:23:15.543693 10348 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001AC178163C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17816708>, because it is not built.
# W0626 16:23:15.543693 10348 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001AC17816708>, because it is not built.
# W0626 16:23:30.950699 10348 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# I0626 16:23:35.678702 10348 builder_impl.py:780] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config
# I0626 16:23:36.281703 10348 config_util.py:254] Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config

# %% [markdown]
# ## Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport

# %%
# !{command}
# Out:
# Writing weight file Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport\model.json...
# 2022-06-26 16:31:19.306379: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-26 16:31:20.967404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-06-26 16:31:29.984749: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2022-06-26 16:31:29.986576: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2022-06-26 16:31:29.989541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-06-26 16:31:30.266809: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 3786 nodes (3376), 5059 edges (4642), time = 162.738ms.
#   function_optimizer: function_optimizer did nothing. time = 4.189ms.
#
# 2022-06-26 16:31:33.662407: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   debug_stripper: Graph size after: 3501 nodes (0), 4840 edges (0), time = 14.006ms.
#   model_pruner: Graph size after: 3058 nodes (-443), 4397 edges (-443), time = 50.747ms.
#   constant_folding: Graph size after: 1562 nodes (-1496), 2671 edges (-1726), time = 196.443ms.
#   arithmetic_optimizer: Graph size after: 1580 nodes (18), 2683 edges (12), time = 36.075ms.
#   dependency_optimizer: Graph size after: 1479 nodes (-101), 1679 edges (-1004), time = 25.632ms.
#   model_pruner: Graph size after: 1479 nodes (0), 1679 edges (0), time = 13.768ms.
#   constant_folding: Graph size after: 1479 nodes (0), 1679 edges (0), time = 38.605ms.
#   arithmetic_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 28.356ms.
#   dependency_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 18.642ms.
#   debug_stripper: debug_stripper did nothing. time = 2.153ms.
#   model_pruner: Graph size after: 1479 nodes (0), 1679 edges (0), time = 12.074ms.
#   constant_folding: Graph size after: 1479 nodes (0), 1679 edges (0), time = 37.633ms.
#   arithmetic_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 30.347ms.
#   dependency_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 17.701ms.
#   model_pruner: Graph size after: 1479 nodes (0), 1679 edges (0), time = 12.086ms.
#   constant_folding: Graph size after: 1479 nodes (0), 1679 edges (0), time = 36.742ms.
#   arithmetic_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 27.737ms.
#   dependency_optimizer: Graph size after: 1479 nodes (0), 1679 edges (0), time = 15.697ms.
#
# 2022-06-26 16:31:41.799743: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 1443 nodes (-112), 1339 edges (-112), time = 12.144ms.
#   constant_folding: Graph size after: 1139 nodes (-304), 1339 edges (0), time = 62.619ms.
#   arithmetic_optimizer: Graph size after: 1139 nodes (0), 1339 edges (0), time = 24.634ms.
#   dependency_optimizer: Graph size after: 1139 nodes (0), 1339 edges (0), time = 13.64ms.
#   remapper: Graph size after: 1139 nodes (0), 1339 edges (0), time = 7.33ms.
#   constant_folding: Graph size after: 1139 nodes (0), 1339 edges (0), time = 31.18ms.
#   arithmetic_optimizer: Graph size after: 1139 nodes (0), 1339 edges (0), time = 23.846ms.
#   dependency_optimizer: Graph size after: 1139 nodes (0), 1339 edges (0), time = 13.002ms.
#
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._box_prediction_head.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._box_prediction_head.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.regularization_losses.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.regularization_losses.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.__call__.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.__call__.trace_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.__call__.trace_3
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.call_and_return_all_conditional_losses.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.call_and_return_all_conditional_losses.trace_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.call_and_return_all_conditional_losses.trace_3
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.0.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.1.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.2.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.regularization_losses.3.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.regularization_losses.0.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.regularization_losses.1.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-0._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-3.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-3.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-2._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-3.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-3.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-6.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-6.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-4.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-4.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-4._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-5.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-5.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-6.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-6.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-6._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-7.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-7.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-11.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-11.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-8.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-8.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-8._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-9.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-9.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-14.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-14.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-10.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-10.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-10._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-11.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-11.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-12.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-12.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-12._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-13.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-13.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-19.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-19.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-14.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-14.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-14._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-15.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-15.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-22.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-22.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-16.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-16.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-16._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-17.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-17.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-25.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-25.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-18.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-18.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-18._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-19.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-19.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-28.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-28.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-20.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-20.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-20._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-21.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-21.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-31.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-31.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-22.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-22.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-22._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-23.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-23.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-24.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-24.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-24._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-25.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-25.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-36.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-36.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-26.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-26.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-26._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-27.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-27.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-39.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-39.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-28.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-28.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-28._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-29.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-29.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-42.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-42.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-30.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-30.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-30._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-31.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-31.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-45.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-45.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-32.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-32.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-32._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-33.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-33.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-48.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-48.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-34.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-34.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-34._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-35.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-35.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-51.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-51.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-36.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-36.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-36._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-37.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-37.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-54.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-54.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-38.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-38.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-38._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-39.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-39.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-57.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-57.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-40.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-40.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-40._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-41.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-41.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-42.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-42.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-42._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-43.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-43.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-62.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-62.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-44.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-44.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-44._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-45.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-45.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-65.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-65.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-46.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-46.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-46._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-47.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-47.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-68.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-68.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-48.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-48.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-48._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-49.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-49.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-71.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-71.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-50.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-50.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-50._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-51.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-51.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-74.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-74.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-52.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-52.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-52._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-53.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-53.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-77.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-77.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-54.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-54.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-54._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-55.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-55.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-80.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-80.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-56.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-56.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-56._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-57.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-57.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-83.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-83.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-58.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-58.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-58._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-59.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-59.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-86.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-86.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-60.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-60.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-60._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-61.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-61.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-89.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-89.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-62.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-62.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-62._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-63.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-63.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-92.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-92.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-64.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-64.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-64._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-65.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-65.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-66.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-66.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-66._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-67.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-67.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-97.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-97.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-68.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-68.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-68._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-69.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-69.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-100.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-100.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-70.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-70.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-70._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-71.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-71.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-103.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-103.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-72.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-72.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-72._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-73.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-73.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-106.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-106.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-74.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-74.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-74._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-75.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-75.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-109.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer-109.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-76.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-76.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-76._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-77.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.layer_with_weights-77.call_and_return_all_conditional_losses
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.17.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.18.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.19.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.20.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.21.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.22.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.23.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.24.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.25.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.26.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.27.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.28.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.29.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.30.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.31.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.32.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.33.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.34.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.35.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.36.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.37.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.38.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.39.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.40.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.41.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.42.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.43.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.44.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.45.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.46.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.47.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.48.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.49.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.50.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.classification_backbone.regularization_losses.51.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.regularization_losses.0.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.regularization_losses.1.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.regularization_losses.2.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.regularization_losses.3.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.regularization_losses.4.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.top_layers.0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.top_layers.0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.top_layers.0._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.2.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.2.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.5.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.5.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.8.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.8.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.11.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor.keras_api.layers.11.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._box_prediction_head._box_encoder_layers.0.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._box_prediction_head._box_encoder_layers.0.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.0.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.0.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.1.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.1.__call__.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.1.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.1.call_and_return_all_conditional_losses.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.2.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.2.__call__.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.2.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.2.call_and_return_all_conditional_losses.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.3.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.3.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.4.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.4.__call__.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.4.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.4.call_and_return_all_conditional_losses.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.5.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.5.__call__.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.5.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor.keras_api.layers.5.call_and_return_all_conditional_losses.trace_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.1._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.2._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.3.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.3.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.4.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.4.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.5.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.5.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.5._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.6.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.6.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.7.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.7.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.8.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.8.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.8._jit_compiled_convolution_op
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.9.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.9.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.10.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.10.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.5.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.5.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.8.__call__.trace_0
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._model._feature_extractor._fpn_features_generator.keras_api.layers.8.call_and_return_all_conditional_losses.trace_0
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %% [markdown]
# ## Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %% [markdown]
# convert to tflite graph

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport

# %%
# !{command}
# Out:
# 2022-06-26 16:33:14.005114: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-26 16:33:14.492460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-06-26 16:33:20.706543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-06-26 16:33:20.729671: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-06-26 16:33:22.432382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-06-26 16:33:24.665322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000027E8E946288>, because it is not built.
# W0626 16:33:24.996702  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000027E8E946288>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA22C0BC8>, because it is not built.
# W0626 16:33:25.392255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA22C0BC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24E6F48>, because it is not built.
# W0626 16:33:25.392255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24E6F48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA246AC48>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA246AC48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027E9D0A8648>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027E9D0A8648>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24D75C8>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24D75C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA24FF288>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA24FF288>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA24FF608>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA24FF608>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24FFB48>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA24FFB48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA255D108>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA255D108>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA255DAC8>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x0000027EA255DAC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA255D588>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA255D588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2526488>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2526488>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25AD948>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25AD948>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA251B888>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA251B888>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25A2048>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25A2048>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA25A2108>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA25A2108>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25A2B08>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA25A2B08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB369188>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB369188>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB3696C8>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB3696C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB370E48>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB370E48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA259BEC8>, because it is not built.
# W0626 16:33:25.393255  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA259BEC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB524588>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB524588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB526C48>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB526C48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB526CC8>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB526CC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB526188>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB526188>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB538A88>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB538A88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB5389C8>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB5389C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB538748>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB538748>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB56B048>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB56B048>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA252AF08>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA252AF08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA252A688>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA252A688>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB511448>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB511448>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB511B48>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB511B48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB511988>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB511988>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2371408>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2371408>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2555DC8>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2555DC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB56B108>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EFB56B108>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA24C7588>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA24C7588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2541348>, because it is not built.
# W0626 16:33:25.394331  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2541348>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA22C85C8>, because it is not built.
# W0626 16:33:25.395275  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA22C85C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA20D9B48>, because it is not built.
# W0626 16:33:25.395275  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA20D9B48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2434BC8>, because it is not built.
# W0626 16:33:25.395275  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EA2434BC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2434A08>, because it is not built.
# W0626 16:33:25.395275  8476 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000027EA2434A08>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB385088>, because it is not built.
# W0626 16:33:25.395275  8476 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x0000027EFB385088>, because it is not built.
# W0626 16:33:41.032666  8476 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets
# I0626 16:33:45.851504  8476 builder_impl.py:780] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %% [markdown]
# tflite converter

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}

# %% [markdown]
# ## ZIP and export models

# %%
#!tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
#from google.colab import drive
#drive.mount('/content/drive')
